# %%
# %reload_ext dotenv
# %dotenv .env

# %%
import overpy
import sqlite3
import os

from queue import PriorityQueue
from collections import defaultdict
from folium import Map, PolyLine

from classes import GraphNode

api = overpy.Overpass()
connection = sqlite3.connect(os.environ.get('DATABASE_NAME'))
cursor = connection.cursor()

# %% [markdown]
# #### Execute query using Overpass Turbo

# %%
tram_railways_query_result = api.query("""
    [out:json];
    area["name"="Kraków"]->.search_area;
    (
        way["railway"="tram"]["oneway"="yes"](area.search_area);
        >;
    );
    out geom;
""")

# %% [markdown]
# #### Create a graph of nodes and edges

# %%
graph: dict[int, GraphNode] = {}

for item in tram_railways_query_result.ways:
    nodes = item.get_nodes()

    for node in nodes:
        if node.id not in graph:
            graph[node.id] = GraphNode(node.id, node.lat, node.lon)

    for start, end in zip(nodes, nodes[1:]):
        graph[start.id].edges.append(graph[end.id])

list(graph.values())
# Out:
# [GraphNode(id=321437325, latitude=Decimal('50.0724838'), longitude=Decimal('20.0376671')),
#  GraphNode(id=213605067, latitude=Decimal('50.0725312'), longitude=Decimal('20.0373188')),
#  GraphNode(id=3071452252, latitude=Decimal('50.0663517'), longitude=Decimal('19.9585038')),
#  GraphNode(id=3071450411, latitude=Decimal('50.0664205'), longitude=Decimal('19.9584619')),
#  GraphNode(id=3071450414, latitude=Decimal('50.0665347'), longitude=Decimal('19.9583819')),
#  GraphNode(id=3071450415, latitude=Decimal('50.0666227'), longitude=Decimal('19.9583062')),
#  GraphNode(id=3071450416, latitude=Decimal('50.0666625'), longitude=Decimal('19.9582670')),
#  GraphNode(id=3071450417, latitude=Decimal('50.0667182'), longitude=Decimal('19.9582049')),
#  GraphNode(id=3071450418, latitude=Decimal('50.0667704'), longitude=Decimal('19.9581340')),
#  GraphNode(id=276371937, latitude=Decimal('50.0668129'), longitude=Decimal('19.9580691')),
#  GraphNode(id=3071447313, latitude=Decimal('50.0668912'), longitude=Decimal('19.9579235')),
#  GraphNode(id=276371936, latitude=Decimal('50.0669605'), longitude=Decimal('19.9577540')),
#  GraphNode(id=3071447314, latitude=Decimal('50.0669852'), longitude=Decimal('19.9576751')),
#  GraphNode(id=3071447315, latitude=Decimal('50.0670150'), longitude=Decimal('19.9575641')),
#  GraphNode(id=3071450423, latitude=Decimal('50.0670443'), longitude=Decimal('19.9574333')),
#  GraphNode(id=3071447317, latitude=Decimal('50.0670823'), longitude=Decimal('19.9572441')),
#  GraphNode(id=3071447318, latitude=Decimal('50.0671383'), longitude=Decimal('19.9569456')),
#  GraphNode(id=276371935, latitude=Decimal('50.0673056'), longitude=Decimal('19.9560477')),
#  GraphNode(id=3071447319, latitude=Decimal('50.0674813'), longitude=Decimal('19.9551056')),
#  GraphNode(id=3071447320, latitude=Decimal('50.0676541'), longitude=Decimal('19.9541827')),
#  GraphNode(id=3726739231, latitude=Decimal('50.0677758'), longitude=Decimal('19.9535355')),
#  GraphNode(id=1446104195, latitude=Decimal('50.0680013'), longitude=Decimal('19.9523369')),
#  GraphNode(id=3070903594, latitude=Decimal('50.0680986'), longitude=Decimal('19.9518153')),
#  GraphNode(id=276679072, latitude=Decimal('50.0681810'), longitude=Decimal('19.9512931')),
#  GraphNode(id=276679071, latitude=Decimal('50.0682409'), longitude=Decimal('19.9507443')),
#  GraphNode(id=3070903839, latitude=Decimal('50.0682572'), longitude=Decimal('19.9504371')),
#  GraphNode(id=3070902480, latitude=Decimal('50.0682734'), longitude=Decimal('19.9501445')),
#  GraphNode(id=276679069, latitude=Decimal('50.0682768'), longitude=Decimal('19.9498374')),
#  GraphNode(id=276679068, latitude=Decimal('50.0682600'), longitude=Decimal('19.9486887')),
#  GraphNode(id=276679067, latitude=Decimal('50.0682510'), longitude=Decimal('19.9480658')),
#  GraphNode(id=276679066, latitude=Decimal('50.0682455'), longitude=Decimal('19.9477349')),
#  GraphNode(id=3070903600, latitude=Decimal('50.0682308'), longitude=Decimal('19.9467502')),
#  GraphNode(id=276679065, latitude=Decimal('50.0682314'), longitude=Decimal('19.9465001')),
#  GraphNode(id=3070903602, latitude=Decimal('50.0682512'), longitude=Decimal('19.9462607')),
#  GraphNode(id=276679063, latitude=Decimal('50.0682944'), longitude=Decimal('19.9460301')),
#  GraphNode(id=3070903843, latitude=Decimal('50.0683589'), longitude=Decimal('19.9458302')),
#  GraphNode(id=276679062, latitude=Decimal('50.0684592'), longitude=Decimal('19.9456185')),
#  GraphNode(id=3070903858, latitude=Decimal('50.0685522'), longitude=Decimal('19.9454789')),
#  GraphNode(id=3070903611, latitude=Decimal('50.0686958'), longitude=Decimal('19.9453310')),
#  GraphNode(id=276679061, latitude=Decimal('50.0688146'), longitude=Decimal('19.9452472')),
#  GraphNode(id=3070904749, latitude=Decimal('50.0689961'), longitude=Decimal('19.9451756')),
#  GraphNode(id=3070895829, latitude=Decimal('50.0694773'), longitude=Decimal('19.9450958')),
#  GraphNode(id=2425141544, latitude=Decimal('50.0702305'), longitude=Decimal('19.9449820')),
#  GraphNode(id=2420153435, latitude=Decimal('50.0707439'), longitude=Decimal('19.9449088')),
#  GraphNode(id=4543684374, latitude=Decimal('50.0707507'), longitude=Decimal('19.9449078')),
#  GraphNode(id=3070895830, latitude=Decimal('50.0710485'), longitude=Decimal('19.9448658')),
#  GraphNode(id=3070904341, latitude=Decimal('50.0711784'), longitude=Decimal('19.9448579')),
#  GraphNode(id=276680434, latitude=Decimal('50.0713648'), longitude=Decimal('19.9448788')),
#  GraphNode(id=276679058, latitude=Decimal('50.0716420'), longitude=Decimal('19.9449477')),
#  GraphNode(id=3070899299, latitude=Decimal('50.0719851'), longitude=Decimal('19.9450311')),
#  GraphNode(id=2424198687, latitude=Decimal('50.0721805'), longitude=Decimal('19.9450776')),
#  GraphNode(id=1886376902, latitude=Decimal('50.0578076'), longitude=Decimal('19.9599112')),
#  GraphNode(id=9051982164, latitude=Decimal('50.0577453'), longitude=Decimal('19.9597082')),
#  GraphNode(id=8551858379, latitude=Decimal('50.0577264'), longitude=Decimal('19.9596364')),
#  GraphNode(id=2427798154, latitude=Decimal('50.0577216'), longitude=Decimal('19.9596081')),
#  GraphNode(id=1895925722, latitude=Decimal('50.0576836'), longitude=Decimal('19.9593592')),
#  GraphNode(id=967037677, latitude=Decimal('50.0716803'), longitude=Decimal('20.0360300')),
#  GraphNode(id=213602145, latitude=Decimal('50.0716931'), longitude=Decimal('20.0358181')),
#  GraphNode(id=321437391, latitude=Decimal('50.0717112'), longitude=Decimal('20.0354966')),
#  GraphNode(id=8284515559, latitude=Decimal('50.0725396'), longitude=Decimal('20.0372530')),
#  GraphNode(id=1769087805, latitude=Decimal('50.0725669'), longitude=Decimal('20.0370513')),
#  GraphNode(id=10922204744, latitude=Decimal('50.0725749'), longitude=Decimal('20.0370113')),
#  GraphNode(id=8811729753, latitude=Decimal('50.0725836'), longitude=Decimal('20.0369740')),
#  GraphNode(id=10922204743, latitude=Decimal('50.0725938'), longitude=Decimal('20.0369370')),
#  GraphNode(id=1769087806, latitude=Decimal('50.0726041'), longitude=Decimal('20.0369014')),
#  GraphNode(id=10922204742, latitude=Decimal('50.0726194'), longitude=Decimal('20.0368609')),
#  GraphNode(id=10922204741, latitude=Decimal('50.0726290'), longitude=Decimal('20.0368370')),
#  GraphNode(id=1769087809, latitude=Decimal('50.0726381'), longitude=Decimal('20.0368155')),
#  GraphNode(id=10922204740, latitude=Decimal('50.0726511'), longitude=Decimal('20.0367896')),
#  GraphNode(id=10922204739, latitude=Decimal('50.0726682'), longitude=Decimal('20.0367584')),
#  GraphNode(id=1769087812, latitude=Decimal('50.0726853'), longitude=Decimal('20.0367305')),
#  GraphNode(id=8284515565, latitude=Decimal('50.0727759'), longitude=Decimal('20.0366011')),
#  GraphNode(id=655410587, latitude=Decimal('50.0729622'), longitude=Decimal('20.0363368')),
#  GraphNode(id=8294375549, latitude=Decimal('50.0744079'), longitude=Decimal('20.0343157')),
#  GraphNode(id=8294375551, latitude=Decimal('50.0753005'), longitude=Decimal('20.0330667')),
#  GraphNode(id=8294375555, latitude=Decimal('50.0756769'), longitude=Decimal('20.0325410')),
#  GraphNode(id=8294375553, latitude=Decimal('50.0757939'), longitude=Decimal('20.0323829')),
#  GraphNode(id=1769087828, latitude=Decimal('50.0765045'), longitude=Decimal('20.0314521')),
#  GraphNode(id=8294375557, latitude=Decimal('50.0766522'), longitude=Decimal('20.0312611')),
#  GraphNode(id=8294375559, latitude=Decimal('50.0767366'), longitude=Decimal('20.0311505')),
#  GraphNode(id=8294375561, latitude=Decimal('50.0768208'), longitude=Decimal('20.0310392')),
#  GraphNode(id=8309132972, latitude=Decimal('50.0780117'), longitude=Decimal('20.0294895')),
#  GraphNode(id=8309132967, latitude=Decimal('50.0780796'), longitude=Decimal('20.0294003')),
#  GraphNode(id=8309132970, latitude=Decimal('50.0781573'), longitude=Decimal('20.0292996')),
#  GraphNode(id=8309132975, latitude=Decimal('50.0792343'), longitude=Decimal('20.0278958')),
#  GraphNode(id=8309132974, latitude=Decimal('50.0793482'), longitude=Decimal('20.0277463')),
#  GraphNode(id=1769087862, latitude=Decimal('50.0794217'), longitude=Decimal('20.0276503')),
#  GraphNode(id=2427182534, latitude=Decimal('50.0944120'), longitude=Decimal('20.0129179')),
#  GraphNode(id=2427182537, latitude=Decimal('50.0945473'), longitude=Decimal('20.0127296')),
#  GraphNode(id=10584197410, latitude=Decimal('50.0945766'), longitude=Decimal('20.0126926')),
#  GraphNode(id=213645125, latitude=Decimal('50.0945994'), longitude=Decimal('20.0126682')),
#  GraphNode(id=10584197409, latitude=Decimal('50.0946288'), longitude=Decimal('20.0126418')),
#  GraphNode(id=4556203756, latitude=Decimal('50.0946550'), longitude=Decimal('20.0126210')),
#  GraphNode(id=10584197408, latitude=Decimal('50.0946871'), longitude=Decimal('20.0126008')),
#  GraphNode(id=213645126, latitude=Decimal('50.0947168'), longitude=Decimal('20.0125856')),
#  GraphNode(id=10584197407, latitude=Decimal('50.0947457'), longitude=Decimal('20.0125756')),
#  GraphNode(id=4556203751, latitude=Decimal('50.0947780'), longitude=Decimal('20.0125665')),
#  GraphNode(id=10584197406, latitude=Decimal('50.0948044'), longitude=Decimal('20.0125622')),
#  GraphNode(id=4556203752, latitude=Decimal('50.0948296'), longitude=Decimal('20.0125607')),
#  GraphNode(id=10584197405, latitude=Decimal('50.0948582'), longitude=Decimal('20.0125628')),
#  GraphNode(id=213645127, latitude=Decimal('50.0949411'), longitude=Decimal('20.0125724')),
#  GraphNode(id=1301798285, latitude=Decimal('50.0944509'), longitude=Decimal('20.0119168')),
#  GraphNode(id=10584197386, latitude=Decimal('50.0944701'), longitude=Decimal('20.0119984')),
#  GraphNode(id=10584197385, latitude=Decimal('50.0944856'), longitude=Decimal('20.0120496')),
#  GraphNode(id=4556203758, latitude=Decimal('50.0945027'), longitude=Decimal('20.0120917')),
#  GraphNode(id=213645254, latitude=Decimal('50.0945221'), longitude=Decimal('20.0121326')),
#  GraphNode(id=10584197390, latitude=Decimal('50.0945454'), longitude=Decimal('20.0121701')),
#  GraphNode(id=213645327, latitude=Decimal('50.0945661'), longitude=Decimal('20.0122019')),
#  GraphNode(id=213645325, latitude=Decimal('50.0947487'), longitude=Decimal('20.0124456')),
#  GraphNode(id=10584197392, latitude=Decimal('50.0947742'), longitude=Decimal('20.0124742')),
#  GraphNode(id=1301805127, latitude=Decimal('50.0947998'), longitude=Decimal('20.0125005')),
#  GraphNode(id=10584197403, latitude=Decimal('50.0948278'), longitude=Decimal('20.0125235')),
#  GraphNode(id=4556203755, latitude=Decimal('50.0948535'), longitude=Decimal('20.0125422')),
#  GraphNode(id=8443884963, latitude=Decimal('50.0948826'), longitude=Decimal('20.0125565')),
#  GraphNode(id=10584197404, latitude=Decimal('50.0949120'), longitude=Decimal('20.0125669')),
#  GraphNode(id=243781985, latitude=Decimal('50.0624346'), longitude=Decimal('19.9826582')),
#  GraphNode(id=243781984, latitude=Decimal('50.0621529'), longitude=Decimal('19.9820754')),
#  GraphNode(id=213597122, latitude=Decimal('50.0615822'), longitude=Decimal('19.9808897')),
#  GraphNode(id=638606075, latitude=Decimal('50.0612878'), longitude=Decimal('19.9802774')),
#  GraphNode(id=1764579366, latitude=Decimal('50.0609116'), longitude=Decimal('19.9794995')),
#  GraphNode(id=2420286352, latitude=Decimal('50.0664986'), longitude=Decimal('19.9390606')),
#  GraphNode(id=11104115575, latitude=Decimal('50.0665276'), longitude=Decimal('19.9390460')),
#  GraphNode(id=11104115574, latitude=Decimal('50.0665615'), longitude=Decimal('19.9390309')),
#  GraphNode(id=2420286354, latitude=Decimal('50.0666064'), longitude=Decimal('19.9390145')),
#  GraphNode(id=10171224934, latitude=Decimal('50.0675754'), longitude=Decimal('19.9386766')),
#  GraphNode(id=4555683736, latitude=Decimal('50.0688257'), longitude=Decimal('19.9383052')),
#  GraphNode(id=10171224936, latitude=Decimal('50.0688471'), longitude=Decimal('19.9382933')),
#  GraphNode(id=4555683737, latitude=Decimal('50.0689298'), longitude=Decimal('19.9382474')),
#  GraphNode(id=2420286360, latitude=Decimal('50.0690158'), longitude=Decimal('19.9381760')),
#  GraphNode(id=10171224946, latitude=Decimal('50.0692094'), longitude=Decimal('19.9379801')),
#  GraphNode(id=10171224945, latitude=Decimal('50.0693186'), longitude=Decimal('19.9378696')),
#  GraphNode(id=10171224948, latitude=Decimal('50.0694596'), longitude=Decimal('19.9377269')),
#  GraphNode(id=2420286363, latitude=Decimal('50.0695183'), longitude=Decimal('19.9376675')),
#  GraphNode(id=2423789754, latitude=Decimal('50.0696427'), longitude=Decimal('19.9375456')),
#  GraphNode(id=10171223675, latitude=Decimal('50.0699327'), longitude=Decimal('19.9372596')),
#  GraphNode(id=2420286367, latitude=Decimal('50.0704619'), longitude=Decimal('19.9367377')),
#  GraphNode(id=2420286369, latitude=Decimal('50.0706370'), longitude=Decimal('19.9365915')),
#  GraphNode(id=2420286371, latitude=Decimal('50.0708261'), longitude=Decimal('19.9364725')),
#  GraphNode(id=10171224953, latitude=Decimal('50.0712395'), longitude=Decimal('19.9362595')),
#  GraphNode(id=2420286373, latitude=Decimal('50.0713191'), longitude=Decimal('19.9362185')),
#  GraphNode(id=10171224954, latitude=Decimal('50.0713631'), longitude=Decimal('19.9362007')),
#  GraphNode(id=10171224951, latitude=Decimal('50.0714772'), longitude=Decimal('19.9361545')),
#  GraphNode(id=2420286375, latitude=Decimal('50.0715434'), longitude=Decimal('19.9361277')),
#  GraphNode(id=2420286376, latitude=Decimal('50.0721467'), longitude=Decimal('19.9359253')),
#  GraphNode(id=4555686619, latitude=Decimal('50.0722658'), longitude=Decimal('19.9358911')),
#  GraphNode(id=5242306390, latitude=Decimal('50.0722884'), longitude=Decimal('19.9358875')),
#  GraphNode(id=2420286378, latitude=Decimal('50.0723662'), longitude=Decimal('19.9358750')),
#  GraphNode(id=10171224958, latitude=Decimal('50.0723899'), longitude=Decimal('19.9358735')),
#  GraphNode(id=10171224957, latitude=Decimal('50.0729996'), longitude=Decimal('19.9358336')),
#  GraphNode(id=2420286381, latitude=Decimal('50.0731477'), longitude=Decimal('19.9358247')),
#  GraphNode(id=11381035808, latitude=Decimal('50.0731768'), longitude=Decimal('19.9358267')),
#  GraphNode(id=11381035809, latitude=Decimal('50.0732055'), longitude=Decimal('19.9358343')),
#  GraphNode(id=2420286383, latitude=Decimal('50.0732404'), longitude=Decimal('19.9358501')),
#  GraphNode(id=11381035810, latitude=Decimal('50.0732684'), longitude=Decimal('19.9358678')),
#  GraphNode(id=11381035811, latitude=Decimal('50.0732994'), longitude=Decimal('19.9358936')),
#  GraphNode(id=2420286385, latitude=Decimal('50.0733262'), longitude=Decimal('19.9359234')),
#  GraphNode(id=11381035812, latitude=Decimal('50.0733545'), longitude=Decimal('19.9359635')),
#  GraphNode(id=2420286387, latitude=Decimal('50.0733828'), longitude=Decimal('19.9360151')),
#  GraphNode(id=11381035813, latitude=Decimal('50.0733999'), longitude=Decimal('19.9360559')),
#  GraphNode(id=11381035814, latitude=Decimal('50.0734150'), longitude=Decimal('19.9361035')),
#  GraphNode(id=11381035815, latitude=Decimal('50.0734257'), longitude=Decimal('19.9361443')),
#  GraphNode(id=2420286389, latitude=Decimal('50.0734343'), longitude=Decimal('19.9361879')),
#  GraphNode(id=11381035825, latitude=Decimal('50.0734392'), longitude=Decimal('19.9362211')),
#  GraphNode(id=2423804379, latitude=Decimal('50.0734866'), longitude=Decimal('19.9365818')),
#  GraphNode(id=2420286390, latitude=Decimal('50.0735239'), longitude=Decimal('19.9368650')),
#  GraphNode(id=11381035920, latitude=Decimal('50.0735328'), longitude=Decimal('19.9369309')),
#  GraphNode(id=11381035921, latitude=Decimal('50.0735401'), longitude=Decimal('19.9370028')),
#  GraphNode(id=2420286391, latitude=Decimal('50.0735460'), longitude=Decimal('19.9370698')),
#  GraphNode(id=11381035922, latitude=Decimal('50.0735510'), longitude=Decimal('19.9371515')),
#  GraphNode(id=11381035923, latitude=Decimal('50.0735544'), longitude=Decimal('19.9372372')),
#  GraphNode(id=2423804387, latitude=Decimal('50.0735560'), longitude=Decimal('19.9373246')),
#  GraphNode(id=2420286392, latitude=Decimal('50.0735570'), longitude=Decimal('19.9376312')),
#  GraphNode(id=11381035880, latitude=Decimal('50.0735578'), longitude=Decimal('19.9376738')),
#  GraphNode(id=2420286393, latitude=Decimal('50.0735598'), longitude=Decimal('19.9377134')),
#  GraphNode(id=11381035881, latitude=Decimal('50.0735627'), longitude=Decimal('19.9377474')),
#  GraphNode(id=8883915295, latitude=Decimal('50.0735666'), longitude=Decimal('19.9377780')),
#  GraphNode(id=2420286394, latitude=Decimal('50.0735709'), longitude=Decimal('19.9378006')),
#  GraphNode(id=11381035879, latitude=Decimal('50.0735783'), longitude=Decimal('19.9378308')),
#  GraphNode(id=11381035878, latitude=Decimal('50.0735876'), longitude=Decimal('19.9378584')),
#  GraphNode(id=5475733669, latitude=Decimal('50.0735983'), longitude=Decimal('19.9378849')),
#  GraphNode(id=2423804390, latitude=Decimal('50.0736101'), longitude=Decimal('19.9379108')),
#  GraphNode(id=11381035877, latitude=Decimal('50.0736187'), longitude=Decimal('19.9379267')),
#  GraphNode(id=11381035876, latitude=Decimal('50.0736311'), longitude=Decimal('19.9379462')),
#  GraphNode(id=2420286398, latitude=Decimal('50.0736500'), longitude=Decimal('19.9379751')),
#  GraphNode(id=10171224939, latitude=Decimal('50.0736669'), longitude=Decimal('19.9379991')),
#  GraphNode(id=10171224942, latitude=Decimal('50.0737158'), longitude=Decimal('19.9380639')),
#  GraphNode(id=10171224943, latitude=Decimal('50.0737659'), longitude=Decimal('19.9381324')),
#  GraphNode(id=2420286399, latitude=Decimal('50.0738480'), longitude=Decimal('19.9382456')),
#  GraphNode(id=10171224931, latitude=Decimal('50.0740555'), longitude=Decimal('19.9385292')),
#  GraphNode(id=10171224927, latitude=Decimal('50.0740992'), longitude=Decimal('19.9385829')),
#  GraphNode(id=10171224928, latitude=Decimal('50.0742415'), longitude=Decimal('19.9387758')),
#  GraphNode(id=11381035988, latitude=Decimal('50.0746714'), longitude=Decimal('19.9393587')),
#  GraphNode(id=11381035990, latitude=Decimal('50.0747903'), longitude=Decimal('19.9395172')),
#  GraphNode(id=11381035994, latitude=Decimal('50.0748626'), longitude=Decimal('19.9396106')),
#  GraphNode(id=2420286404, latitude=Decimal('50.0751439'), longitude=Decimal('19.9399630')),
#  GraphNode(id=10058377896, latitude=Decimal('50.0751695'), longitude=Decimal('19.9399971')),
#  GraphNode(id=10058377895, latitude=Decimal('50.0751863'), longitude=Decimal('19.9400221')),
#  GraphNode(id=1472385507, latitude=Decimal('50.0751919'), longitude=Decimal('19.9400313')),
#  GraphNode(id=10058377897, latitude=Decimal('50.0752014'), longitude=Decimal('19.9400467')),
#  GraphNode(id=10058377898, latitude=Decimal('50.0752180'), longitude=Decimal('19.9400756')),
#  GraphNode(id=258237419, latitude=Decimal('50.0752357'), longitude=Decimal('19.9401117')),
#  GraphNode(id=10058377900, latitude=Decimal('50.0752498'), longitude=Decimal('19.9401449')),
#  GraphNode(id=10058377899, latitude=Decimal('50.0752587'), longitude=Decimal('19.9401675')),
#  GraphNode(id=10058377901, latitude=Decimal('50.0752673'), longitude=Decimal('19.9401903')),
#  GraphNode(id=1472540197, latitude=Decimal('50.0752853'), longitude=Decimal('19.9402381')),
#  GraphNode(id=10058377891, latitude=Decimal('50.0753746'), longitude=Decimal('19.9404893')),
#  GraphNode(id=8753082235, latitude=Decimal('50.0754623'), longitude=Decimal('19.9407360')),
#  GraphNode(id=258237422, latitude=Decimal('50.0755068'), longitude=Decimal('19.9408583')),
#  GraphNode(id=272085817, latitude=Decimal('50.0819861'), longitude=Decimal('19.9353082')),
#  GraphNode(id=257656073, latitude=Decimal('50.0824619'), longitude=Decimal('19.9349481')),
#  GraphNode(id=213585984, latitude=Decimal('50.0668092'), longitude=Decimal('19.9749274')),
#  GraphNode(id=11402751785, latitude=Decimal('50.0667916'), longitude=Decimal('19.9748534')),
#  GraphNode(id=3720119291, latitude=Decimal('50.0667763'), longitude=Decimal('19.9747834')),
#  GraphNode(id=1768224687, latitude=Decimal('50.0667467'), longitude=Decimal('19.9746168')),
#  GraphNode(id=1768224686, latitude=Decimal('50.0667192'), longitude=Decimal('19.9744236')),
#  GraphNode(id=213585985, latitude=Decimal('50.0666967'), longitude=Decimal('19.9741959')),
#  GraphNode(id=1768224682, latitude=Decimal('50.0666723'), longitude=Decimal('19.9738021')),
#  GraphNode(id=213585986, latitude=Decimal('50.0666597'), longitude=Decimal('19.9736114')),
#  GraphNode(id=931906231, latitude=Decimal('50.0666403'), longitude=Decimal('19.9732544')),
#  GraphNode(id=1768224679, latitude=Decimal('50.0666358'), longitude=Decimal('19.9731414')),
#  GraphNode(id=1768224678, latitude=Decimal('50.0666306'), longitude=Decimal('19.9730254')),
#  GraphNode(id=213585987, latitude=Decimal('50.0666242'), longitude=Decimal('19.9728121')),
#  GraphNode(id=1768224667, latitude=Decimal('50.0665639'), longitude=Decimal('19.9708752')),
#  GraphNode(id=213585991, latitude=Decimal('50.0665544'), longitude=Decimal('19.9705909')),
#  GraphNode(id=213585992, latitude=Decimal('50.0665369'), longitude=Decimal('19.9700126')),
#  GraphNode(id=3720119284, latitude=Decimal('50.0665345'), longitude=Decimal('19.9697182')),
#  GraphNode(id=1768224656, latitude=Decimal('50.0665336'), longitude=Decimal('19.9691560')),
#  GraphNode(id=10980082783, latitude=Decimal('50.0665333'), longitude=Decimal('19.9690968')),
#  GraphNode(id=213585996, latitude=Decimal('50.0665318'), longitude=Decimal('19.9687864')),
#  GraphNode(id=1768224658, latitude=Decimal('50.0665373'), longitude=Decimal('19.9683079')),
#  GraphNode(id=1768224660, latitude=Decimal('50.0665456'), longitude=Decimal('19.9678894')),
#  GraphNode(id=213585999, latitude=Decimal('50.0665577'), longitude=Decimal('19.9673065')),
#  GraphNode(id=213586001, latitude=Decimal('50.0665924'), longitude=Decimal('19.9654867')),
#  GraphNode(id=1768224672, latitude=Decimal('50.0665931'), longitude=Decimal('19.9653032')),
#  GraphNode(id=213586004, latitude=Decimal('50.0665915'), longitude=Decimal('19.9652052')),
#  GraphNode(id=1768224671, latitude=Decimal('50.0665906'), longitude=Decimal('19.9651346')),
#  GraphNode(id=1768224670, latitude=Decimal('50.0665857'), longitude=Decimal('19.9650296')),
#  GraphNode(id=1768224669, latitude=Decimal('50.0665833'), longitude=Decimal('19.9649695')),
#  GraphNode(id=213586005, latitude=Decimal('50.0665674'), longitude=Decimal('19.9647613')),
#  GraphNode(id=1768224668, latitude=Decimal('50.0665546'), longitude=Decimal('19.9646231')),
#  GraphNode(id=213586006, latitude=Decimal('50.0665386'), longitude=Decimal('19.9644932')),
#  GraphNode(id=1768224661, latitude=Decimal('50.0665226'), longitude=Decimal('19.9643741')),
#  GraphNode(id=1668947288, latitude=Decimal('50.0664743'), longitude=Decimal('19.9640335')),
#  GraphNode(id=213586008, latitude=Decimal('50.0664309'), longitude=Decimal('19.9637321')),
#  GraphNode(id=3720119272, latitude=Decimal('50.0660302'), longitude=Decimal('19.9609320')),
#  GraphNode(id=213586497, latitude=Decimal('50.0660072'), longitude=Decimal('19.9607618')),
#  GraphNode(id=213586498, latitude=Decimal('50.0659552'), longitude=Decimal('19.9604605')),
#  GraphNode(id=3071450824, latitude=Decimal('50.0659292'), longitude=Decimal('19.9603499')),
#  GraphNode(id=1887812666, latitude=Decimal('50.0659000'), longitude=Decimal('19.9602384')),
#  GraphNode(id=2219344851, latitude=Decimal('50.0737022'), longitude=Decimal('19.9449209')),
#  GraphNode(id=6697482914, latitude=Decimal('50.0737811'), longitude=Decimal('19.9448807')),
#  GraphNode(id=1326779475, latitude=Decimal('50.0738498'), longitude=Decimal('19.9448457')),
#  GraphNode(id=2219344857, latitude=Decimal('50.0741166'), longitude=Decimal('19.9447041')),
#  GraphNode(id=261704103, latitude=Decimal('50.0742749'), longitude=Decimal('19.9446084')),
#  GraphNode(id=1326779517, latitude=Decimal('50.0743914'), longitude=Decimal('19.9445207')),
#  GraphNode(id=310654620, latitude=Decimal('50.0745192'), longitude=Decimal('19.9444104')),
#  GraphNode(id=310654623, latitude=Decimal('50.0746094'), longitude=Decimal('19.9443134')),
#  GraphNode(id=2219344868, latitude=Decimal('50.0746997'), longitude=Decimal('19.9442048')),
#  GraphNode(id=261704026, latitude=Decimal('50.0748373'), longitude=Decimal('19.9440164')),
#  GraphNode(id=261704101, latitude=Decimal('50.0749493'), longitude=Decimal('19.9438193')),
#  GraphNode(id=310654624, latitude=Decimal('50.0750382'), longitude=Decimal('19.9436387')),
#  GraphNode(id=261704113, latitude=Decimal('50.0751383'), longitude=Decimal('19.9433859')),
#  GraphNode(id=310654622, latitude=Decimal('50.0753035'), longitude=Decimal('19.9428832')),
#  GraphNode(id=310654621, latitude=Decimal('50.0754115'), longitude=Decimal('19.9425464')),
#  GraphNode(id=1471233537, latitude=Decimal('50.0754965'), longitude=Decimal('19.9422481')),
#  GraphNode(id=10058388725, latitude=Decimal('50.0755584'), longitude=Decimal('19.9420102')),
#  GraphNode(id=261704060, latitude=Decimal('50.0756510'), longitude=Decimal('19.9416392')),
#  GraphNode(id=278215728, latitude=Decimal('50.0498182'), longitude=Decimal('19.9524876')),
#  GraphNode(id=1896074170, latitude=Decimal('50.0485400'), longitude=Decimal('19.9541361')),
#  GraphNode(id=3136803133, latitude=Decimal('50.0484968'), longitude=Decimal('19.9541896')),
#  GraphNode(id=206376618, latitude=Decimal('50.0484603'), longitude=Decimal('19.9542299')),
#  GraphNode(id=286858516, latitude=Decimal('50.0869103'), longitude=Decimal('20.0469145')),
#  GraphNode(id=286858519, latitude=Decimal('50.0868738'), longitude=Decimal('20.0465382')),
#  GraphNode(id=10285274825, latitude=Decimal('50.0866074'), longitude=Decimal('20.0438303')),
#  GraphNode(id=9040509236, latitude=Decimal('50.0864919'), longitude=Decimal('20.0426915')),
#  GraphNode(id=213585840, latitude=Decimal('50.0864414'), longitude=Decimal('20.0421850')),
#  GraphNode(id=11226625862, latitude=Decimal('50.0864299'), longitude=Decimal('20.0420682')),
#  GraphNode(id=1769088018, latitude=Decimal('50.0864189'), longitude=Decimal('20.0419666')),
#  GraphNode(id=213585842, latitude=Decimal('50.0864042'), longitude=Decimal('20.0418630')),
#  GraphNode(id=1769088013, latitude=Decimal('50.0863850'), longitude=Decimal('20.0417550')),
#  GraphNode(id=11226625861, latitude=Decimal('50.0863689'), longitude=Decimal('20.0416690')),
#  GraphNode(id=1769088006, latitude=Decimal('50.0863489'), longitude=Decimal('20.0415679')),
#  GraphNode(id=213585843, latitude=Decimal('50.0863173'), longitude=Decimal('20.0414343')),
#  GraphNode(id=9040509239, latitude=Decimal('50.0862630'), longitude=Decimal('20.0412245')),
#  GraphNode(id=11640260558, latitude=Decimal('50.0861314'), longitude=Decimal('20.0407117')),
#  GraphNode(id=1769088000, latitude=Decimal('50.0858839'), longitude=Decimal('20.0397536')),
#  GraphNode(id=213585849, latitude=Decimal('50.0858576'), longitude=Decimal('20.0396604')),
#  GraphNode(id=1769087995, latitude=Decimal('50.0858282'), longitude=Decimal('20.0395612')),
#  GraphNode(id=1769087988, latitude=Decimal('50.0857984'), longitude=Decimal('20.0394667')),
#  GraphNode(id=213585850, latitude=Decimal('50.0857682'), longitude=Decimal('20.0393798')),
#  GraphNode(id=11219480550, latitude=Decimal('50.0857368'), longitude=Decimal('20.0392930')),
#  GraphNode(id=1769087983, latitude=Decimal('50.0856993'), longitude=Decimal('20.0391965')),
#  GraphNode(id=213585852, latitude=Decimal('50.0856572'), longitude=Decimal('20.0390947')),
#  GraphNode(id=1769087979, latitude=Decimal('50.0856173'), longitude=Decimal('20.0390049')),
#  GraphNode(id=11219480549, latitude=Decimal('50.0855755'), longitude=Decimal('20.0389138')),
#  GraphNode(id=213585855, latitude=Decimal('50.0853912'), longitude=Decimal('20.0385224')),
#  GraphNode(id=8300966842, latitude=Decimal('50.0853028'), longitude=Decimal('20.0383438')),
#  GraphNode(id=8300966840, latitude=Decimal('50.0852048'), longitude=Decimal('20.0381448')),
#  GraphNode(id=8300966838, latitude=Decimal('50.0850591'), longitude=Decimal('20.0378694')),
#  GraphNode(id=213585864, latitude=Decimal('50.0824060'), longitude=Decimal('20.0329435')),
#  GraphNode(id=8284483158, latitude=Decimal('50.0822513'), longitude=Decimal('20.0326607')),
#  GraphNode(id=8284483156, latitude=Decimal('50.0821384'), longitude=Decimal('20.0324504')),
#  GraphNode(id=8284483160, latitude=Decimal('50.0820402'), longitude=Decimal('20.0322669')),
#  GraphNode(id=777395551, latitude=Decimal('50.0818938'), longitude=Decimal('20.0319954')),
#  GraphNode(id=9040509235, latitude=Decimal('50.0813786'), longitude=Decimal('20.0310425')),
#  GraphNode(id=1417867070, latitude=Decimal('50.0803808'), longitude=Decimal('20.0291883')),
#  GraphNode(id=1769087958, latitude=Decimal('50.0803372'), longitude=Decimal('20.0290995')),
#  GraphNode(id=1769087956, latitude=Decimal('50.0803089'), longitude=Decimal('20.0290363')),
#  GraphNode(id=213585870, latitude=Decimal('50.0802844'), longitude=Decimal('20.0289730')),
#  GraphNode(id=1769087953, latitude=Decimal('50.0802631'), longitude=Decimal('20.0289136')),
#  GraphNode(id=1769087949, latitude=Decimal('50.0802134'), longitude=Decimal('20.0287698')),
#  GraphNode(id=8309440387, latitude=Decimal('50.0799881'), longitude=Decimal('20.0280390')),
#  GraphNode(id=8996157956, latitude=Decimal('50.0799608'), longitude=Decimal('20.0279619')),
#  GraphNode(id=2386355370, latitude=Decimal('50.0799294'), longitude=Decimal('20.0278874')),
#  GraphNode(id=2219344850, latitude=Decimal('50.0736838'), longitude=Decimal('19.9448665')),
#  GraphNode(id=7458298537, latitude=Decimal('50.0734058'), longitude=Decimal('19.9449429')),
#  GraphNode(id=2420286405, latitude=Decimal('50.0750481'), longitude=Decimal('19.9397924')),
#  GraphNode(id=2423804378, latitude=Decimal('50.0749597'), longitude=Decimal('19.9396806')),
#  GraphNode(id=288935454, latitude=Decimal('50.0810609'), longitude=Decimal('19.8910513')),
#  GraphNode(id=2419986549, latitude=Decimal('50.0812456'), longitude=Decimal('19.8901342')),
#  GraphNode(id=2419959861, latitude=Decimal('50.0774511'), longitude=Decimal('19.9017084')),
#  GraphNode(id=4555661197, latitude=Decimal('50.0775256'), longitude=Decimal('19.9015078')),
#  GraphNode(id=2419959868, latitude=Decimal('50.0775600'), longitude=Decimal('19.9014007')),
#  GraphNode(id=8111629535, latitude=Decimal('50.0775714'), longitude=Decimal('19.9013566')),
#  GraphNode(id=288929763, latitude=Decimal('50.0775910'), longitude=Decimal('19.9012808')),
#  GraphNode(id=8753082239, latitude=Decimal('50.0776155'), longitude=Decimal('19.9012007')),
#  GraphNode(id=2419986537, latitude=Decimal('50.0813371'), longitude=Decimal('19.8896830')),
#  GraphNode(id=6148308975, latitude=Decimal('50.0813817'), longitude=Decimal('19.8894640')),
#  GraphNode(id=4092034290, latitude=Decimal('50.0813962'), longitude=Decimal('19.8893926')),
#  GraphNode(id=8638161956, latitude=Decimal('50.0814221'), longitude=Decimal('19.8892654')),
#  GraphNode(id=2524915090, latitude=Decimal('50.0814313'), longitude=Decimal('19.8892166')),
#  GraphNode(id=4092034296, latitude=Decimal('50.0814478'), longitude=Decimal('19.8891327')),
#  GraphNode(id=4097880339, latitude=Decimal('50.0814610'), longitude=Decimal('19.8890678')),
#  GraphNode(id=3998563420, latitude=Decimal('50.0814674'), longitude=Decimal('19.8890349')),
#  GraphNode(id=4097880341, latitude=Decimal('50.0814732'), longitude=Decimal('19.8890076')),
#  GraphNode(id=288935471, latitude=Decimal('50.0819003'), longitude=Decimal('19.8869102')),
#  GraphNode(id=10246230173, latitude=Decimal('50.0819346'), longitude=Decimal('19.8867195')),
#  GraphNode(id=288935477, latitude=Decimal('50.0819630'), longitude=Decimal('19.8865289')),
#  GraphNode(id=10246230172, latitude=Decimal('50.0819863'), longitude=Decimal('19.8863128')),
#  GraphNode(id=288935480, latitude=Decimal('50.0820053'), longitude=Decimal('19.8860859')),
#  GraphNode(id=10246230171, latitude=Decimal('50.0820130'), longitude=Decimal('19.8859165')),
#  GraphNode(id=288935486, latitude=Decimal('50.0820190'), longitude=Decimal('19.8855867')),
#  GraphNode(id=1314498382, latitude=Decimal('50.0820226'), longitude=Decimal('19.8851850')),
#  GraphNode(id=4016145704, latitude=Decimal('50.0820319'), longitude=Decimal('19.8841595')),
#  GraphNode(id=288937353, latitude=Decimal('50.0820349'), longitude=Decimal('19.8840632')),
#  GraphNode(id=4097128492, latitude=Decimal('50.0820346'), longitude=Decimal('19.8839714')),
#  GraphNode(id=2461475470, latitude=Decimal('50.0820383'), longitude=Decimal('19.8837676')),
#  GraphNode(id=2419986541, latitude=Decimal('50.0820443'), longitude=Decimal('19.8831004')),
#  GraphNode(id=2418596873, latitude=Decimal('50.0493177'), longitude=Decimal('19.9333811')),
#  GraphNode(id=2988492043, latitude=Decimal('50.0495775'), longitude=Decimal('19.9342142')),
#  GraphNode(id=2988492136, latitude=Decimal('50.0496052'), longitude=Decimal('19.9342939')),
#  GraphNode(id=288493178, latitude=Decimal('50.0499632'), longitude=Decimal('19.9354273')),
#  GraphNode(id=1890503293, latitude=Decimal('50.0242596'), longitude=Decimal('19.9797419')),
#  GraphNode(id=2421888509, latitude=Decimal('50.0241618'), longitude=Decimal('19.9798781')),
#  GraphNode(id=293619179, latitude=Decimal('50.0241182'), longitude=Decimal('19.9799135')),
#  GraphNode(id=3398407617, latitude=Decimal('50.0240712'), longitude=Decimal('19.9799237')),
#  GraphNode(id=2421888505, latitude=Decimal('50.0240396'), longitude=Decimal('19.9799197')),
#  GraphNode(id=293619176, latitude=Decimal('50.0239787'), longitude=Decimal('19.9799015')),
#  GraphNode(id=3385228481, latitude=Decimal('50.0239269'), longitude=Decimal('19.9798614')),
#  GraphNode(id=293616210, latitude=Decimal('50.0238673'), longitude=Decimal('19.9797838')),
#  GraphNode(id=1035710571, latitude=Decimal('50.0237700'), longitude=Decimal('19.9796094')),
#  GraphNode(id=289685325, latitude=Decimal('50.0131087'), longitude=Decimal('19.9488633')),
#  GraphNode(id=4555557391, latitude=Decimal('50.0131383'), longitude=Decimal('19.9488910')),
#  GraphNode(id=9982254737, latitude=Decimal('50.0131871'), longitude=Decimal('19.9489269')),
#  GraphNode(id=9982254741, latitude=Decimal('50.0132249'), longitude=Decimal('19.9489459')),
#  GraphNode(id=289685324, latitude=Decimal('50.0132674'), longitude=Decimal('19.9489612')),
#  GraphNode(id=2374339808, latitude=Decimal('50.0305493'), longitude=Decimal('19.9276480')),
#  GraphNode(id=290038762, latitude=Decimal('50.0305481'), longitude=Decimal('19.9274107')),
#  GraphNode(id=321429391, latitude=Decimal('50.0295553'), longitude=Decimal('19.9358730')),
#  GraphNode(id=9983827689, latitude=Decimal('50.0296126'), longitude=Decimal('19.9356771')),
#  GraphNode(id=7272959271, latitude=Decimal('50.0296465'), longitude=Decimal('19.9355613')),
#  GraphNode(id=261704020, latitude=Decimal('50.0758542'), longitude=Decimal('19.9408216')),
#  GraphNode(id=288925659, latitude=Decimal('50.0758767'), longitude=Decimal('19.9407305')),
#  GraphNode(id=10058377889, latitude=Decimal('50.0759014'), longitude=Decimal('19.9406312')),
#  GraphNode(id=2420286330, latitude=Decimal('50.0760026'), longitude=Decimal('19.9402228')),
#  GraphNode(id=213585981, latitude=Decimal('50.0669152'), longitude=Decimal('19.9752968')),
#  GraphNode(id=213585983, latitude=Decimal('50.0668907'), longitude=Decimal('19.9752228')),
#  GraphNode(id=11402751783, latitude=Decimal('50.0668718'), longitude=Decimal('19.9751625')),
#  GraphNode(id=1768224695, latitude=Decimal('50.0668513'), longitude=Decimal('19.9750915')),
#  GraphNode(id=1314182578, latitude=Decimal('50.0668299'), longitude=Decimal('19.9750120')),
#  GraphNode(id=4555761483, latitude=Decimal('50.0629938'), longitude=Decimal('19.9838262')),
#  GraphNode(id=317042116, latitude=Decimal('50.0628228'), longitude=Decimal('19.9834729')),
#  GraphNode(id=1703504622, latitude=Decimal('50.0732747'), longitude=Decimal('20.0194569')),
#  GraphNode(id=1763772284, latitude=Decimal('50.0732884'), longitude=Decimal('20.0193247')),
#  GraphNode(id=1763772285, latitude=Decimal('50.0733098'), longitude=Decimal('20.0191140')),
#  GraphNode(id=1763772314, latitude=Decimal('50.0733931'), longitude=Decimal('20.0182957')),
#  GraphNode(id=8629187595, latitude=Decimal('50.0733975'), longitude=Decimal('20.0181974')),
#  GraphNode(id=1763772319, latitude=Decimal('50.0733961'), longitude=Decimal('20.0181067')),
#  GraphNode(id=1763772318, latitude=Decimal('50.0733905'), longitude=Decimal('20.0179765')),
#  GraphNode(id=9983164083, latitude=Decimal('50.0733818'), longitude=Decimal('20.0178893')),
#  GraphNode(id=1763772312, latitude=Decimal('50.0733772'), longitude=Decimal('20.0178521')),
#  GraphNode(id=9983164084, latitude=Decimal('50.0733682'), longitude=Decimal('20.0177995')),
#  GraphNode(id=8629187597, latitude=Decimal('50.0733550'), longitude=Decimal('20.0177433')),
#  GraphNode(id=213597906, latitude=Decimal('50.0733401'), longitude=Decimal('20.0176937')),
#  GraphNode(id=8629187599, latitude=Decimal('50.0733226'), longitude=Decimal('20.0176464')),
#  GraphNode(id=9983164082, latitude=Decimal('50.0733044'), longitude=Decimal('20.0176024')),
#  GraphNode(id=1254603106, latitude=Decimal('50.0732831'), longitude=Decimal('20.0175597')),
#  GraphNode(id=8629187598, latitude=Decimal('50.0732429'), longitude=Decimal('20.0174895')),
#  GraphNode(id=9983164074, latitude=Decimal('50.0732093'), longitude=Decimal('20.0174381')),
#  GraphNode(id=213597902, latitude=Decimal('50.0731831'), longitude=Decimal('20.0174015')),
#  GraphNode(id=9983164075, latitude=Decimal('50.0731596'), longitude=Decimal('20.0173704')),
#  GraphNode(id=8309440397, latitude=Decimal('50.0731344'), longitude=Decimal('20.0173394')),
#  GraphNode(id=1763772280, latitude=Decimal('50.0731106'), longitude=Decimal('20.0173118')),
#  GraphNode(id=4037275938, latitude=Decimal('50.0730869'), longitude=Decimal('20.0172880')),
#  GraphNode(id=9983164086, latitude=Decimal('50.0730661'), longitude=Decimal('20.0172669')),
#  GraphNode(id=1768224745, latitude=Decimal('50.0730419'), longitude=Decimal('20.0172434')),
#  GraphNode(id=10923508508, latitude=Decimal('50.0730095'), longitude=Decimal('20.0172155')),
#  GraphNode(id=10923508507, latitude=Decimal('50.0729742'), longitude=Decimal('20.0171875')),
#  GraphNode(id=1763772264, latitude=Decimal('50.0729329'), longitude=Decimal('20.0171593')),
#  GraphNode(id=1768224796, latitude=Decimal('50.0735942'), longitude=Decimal('20.0155619')),
#  GraphNode(id=9983164101, latitude=Decimal('50.0735795'), longitude=Decimal('20.0156910')),
#  GraphNode(id=9983164102, latitude=Decimal('50.0735574'), longitude=Decimal('20.0159020')),
#  GraphNode(id=9983186839, latitude=Decimal('50.0735048'), longitude=Decimal('20.0163873')),
#  GraphNode(id=1768224782, latitude=Decimal('50.0734868'), longitude=Decimal('20.0165487')),
#  GraphNode(id=9983186837, latitude=Decimal('50.0734739'), longitude=Decimal('20.0166672')),
#  GraphNode(id=9983164103, latitude=Decimal('50.0734660'), longitude=Decimal('20.0167474')),
#  GraphNode(id=9983164104, latitude=Decimal('50.0734615'), longitude=Decimal('20.0167951')),
#  GraphNode(id=1768224777, latitude=Decimal('50.0734586'), longitude=Decimal('20.0168323')),
#  GraphNode(id=1768224778, latitude=Decimal('50.0734575'), longitude=Decimal('20.0168721')),
#  GraphNode(id=1768224779, latitude=Decimal('50.0734605'), longitude=Decimal('20.0169533')),
#  GraphNode(id=1768224780, latitude=Decimal('50.0734642'), longitude=Decimal('20.0170013')),
#  GraphNode(id=3629965018, latitude=Decimal('50.0734701'), longitude=Decimal('20.0170476')),
#  GraphNode(id=1254603120, latitude=Decimal('50.0734815'), longitude=Decimal('20.0171066')),
#  GraphNode(id=1768224786, latitude=Decimal('50.0734978'), longitude=Decimal('20.0171699')),
#  GraphNode(id=1768224791, latitude=Decimal('50.0735167'), longitude=Decimal('20.0172298')),
#  GraphNode(id=213585901, latitude=Decimal('50.0735446'), longitude=Decimal('20.0172945')),
#  GraphNode(id=1254603058, latitude=Decimal('50.0735785'), longitude=Decimal('20.0173580')),
#  GraphNode(id=8629187600, latitude=Decimal('50.0736120'), longitude=Decimal('20.0174072')),
#  GraphNode(id=1768224809, latitude=Decimal('50.0736471'), longitude=Decimal('20.0174508')),
#  GraphNode(id=1768224812, latitude=Decimal('50.0737214'), longitude=Decimal('20.0175291')),
#  GraphNode(id=8309440400, latitude=Decimal('50.0737984'), longitude=Decimal('20.0176126')),
#  GraphNode(id=4037275969, latitude=Decimal('50.0738155'), longitude=Decimal('20.0176319')),
#  GraphNode(id=4056142355, latitude=Decimal('50.0738811'), longitude=Decimal('20.0177021')),
#  GraphNode(id=1763772327, latitude=Decimal('50.0739697'), longitude=Decimal('20.0177946')),
#  GraphNode(id=2374339754, latitude=Decimal('50.0297197'), longitude=Decimal('19.9366326')),
#  GraphNode(id=2374339758, latitude=Decimal('50.0297804'), longitude=Decimal('19.9366459')),
#  GraphNode(id=2374339760, latitude=Decimal('50.0298004'), longitude=Decimal('19.9366459')),
#  GraphNode(id=321429536, latitude=Decimal('50.0298424'), longitude=Decimal('19.9366359')),
#  GraphNode(id=370953744, latitude=Decimal('50.0299073'), longitude=Decimal('19.9365927')),
#  GraphNode(id=1701445141, latitude=Decimal('50.0299311'), longitude=Decimal('19.9365620')),
#  GraphNode(id=3115163950, latitude=Decimal('50.0299633'), longitude=Decimal('19.9365108')),
#  GraphNode(id=1877260212, latitude=Decimal('50.0299806'), longitude=Decimal('19.9364656')),
#  GraphNode(id=321429534, latitude=Decimal('50.0299937'), longitude=Decimal('19.9364245')),
#  GraphNode(id=2374339773, latitude=Decimal('50.0300014'), longitude=Decimal('19.9363945')),
#  GraphNode(id=1701445143, latitude=Decimal('50.0300100'), longitude=Decimal('19.9363154')),
#  GraphNode(id=3115163572, latitude=Decimal('50.0300128'), longitude=Decimal('19.9362703')),
#  GraphNode(id=2374339774, latitude=Decimal('50.0300121'), longitude=Decimal('19.9362328')),
#  GraphNode(id=3115163955, latitude=Decimal('50.0300090'), longitude=Decimal('19.9361991')),
#  GraphNode(id=1701445142, latitude=Decimal('50.0300031'), longitude=Decimal('19.9361608')),
#  GraphNode(id=2374339772, latitude=Decimal('50.0299928'), longitude=Decimal('19.9361198')),
#  GraphNode(id=321429533, latitude=Decimal('50.0299764'), longitude=Decimal('19.9360580')),
#  GraphNode(id=321429532, latitude=Decimal('50.0299528'), longitude=Decimal('19.9359702')),
#  GraphNode(id=11212315425, latitude=Decimal('50.0299037'), longitude=Decimal('19.9357817')),
#  GraphNode(id=629106153, latitude=Decimal('50.0298428'), longitude=Decimal('19.9355476')),
#  GraphNode(id=290038770, latitude=Decimal('50.0295802'), longitude=Decimal('19.9364986')),
#  GraphNode(id=8551890321, latitude=Decimal('50.0294553'), longitude=Decimal('19.9364350')),
#  GraphNode(id=8551890320, latitude=Decimal('50.0293274'), longitude=Decimal('19.9363690')),
#  GraphNode(id=9609058955, latitude=Decimal('50.0292470'), longitude=Decimal('19.9363272')),
#  GraphNode(id=2452612521, latitude=Decimal('50.0291899'), longitude=Decimal('19.9362979')),
#  GraphNode(id=321429839, latitude=Decimal('50.0208040'), longitude=Decimal('19.9319293')),
#  GraphNode(id=9983259521, latitude=Decimal('50.0205904'), longitude=Decimal('19.9318306')),
#  GraphNode(id=5446809639, latitude=Decimal('50.0204696'), longitude=Decimal('19.9317677')),
#  GraphNode(id=9740014630, latitude=Decimal('50.0203292'), longitude=Decimal('19.9316963')),
#  GraphNode(id=9914908241, latitude=Decimal('50.0201945'), longitude=Decimal('19.9316248')),
#  GraphNode(id=9914908239, latitude=Decimal('50.0200640'), longitude=Decimal('19.9315575')),
#  GraphNode(id=9983259523, latitude=Decimal('50.0200125'), longitude=Decimal('19.9315323')),
#  GraphNode(id=9914908289, latitude=Decimal('50.0199414'), longitude=Decimal('19.9315019')),
#  GraphNode(id=9609058975, latitude=Decimal('50.0199025'), longitude=Decimal('19.9314869')),
#  GraphNode(id=9914908236, latitude=Decimal('50.0197960'), longitude=Decimal('19.9314422')),
#  GraphNode(id=9914908235, latitude=Decimal('50.0197023'), longitude=Decimal('19.9313996')),
#  GraphNode(id=9914908234, latitude=Decimal('50.0195020'), longitude=Decimal('19.9312971')),
#  GraphNode(id=10805547160, latitude=Decimal('50.0194329'), longitude=Decimal('19.9312616')),
#  GraphNode(id=9609058974, latitude=Decimal('50.0191099'), longitude=Decimal('19.9310958')),
#  GraphNode(id=10805547155, latitude=Decimal('50.0187973'), longitude=Decimal('19.9309354')),
#  GraphNode(id=321429840, latitude=Decimal('50.0187263'), longitude=Decimal('19.9308990')),
#  GraphNode(id=8791104593, latitude=Decimal('50.0185069'), longitude=Decimal('19.9307813')),
#  GraphNode(id=8791104591, latitude=Decimal('50.0184304'), longitude=Decimal('19.9307420')),
#  GraphNode(id=9609058970, latitude=Decimal('50.0182995'), longitude=Decimal('19.9306725')),
#  GraphNode(id=2374339671, latitude=Decimal('50.0181177'), longitude=Decimal('19.9305761')),
#  GraphNode(id=321429841, latitude=Decimal('50.0177572'), longitude=Decimal('19.9303899')),
#  GraphNode(id=629106146, latitude=Decimal('50.0168118'), longitude=Decimal('19.9298976')),
#  GraphNode(id=321429842, latitude=Decimal('50.0165832'), longitude=Decimal('19.9297716')),
#  GraphNode(id=9609058968, latitude=Decimal('50.0165469'), longitude=Decimal('19.9297527')),
#  GraphNode(id=9609058965, latitude=Decimal('50.0159411'), longitude=Decimal('19.9294369')),
#  GraphNode(id=9609058964, latitude=Decimal('50.0158330'), longitude=Decimal('19.9293805')),
#  GraphNode(id=9609058967, latitude=Decimal('50.0150261'), longitude=Decimal('19.9289587')),
#  GraphNode(id=321429844, latitude=Decimal('50.0147295'), longitude=Decimal('19.9288024')),
#  GraphNode(id=3060994165, latitude=Decimal('50.0146959'), longitude=Decimal('19.9287817')),
#  GraphNode(id=321429845, latitude=Decimal('50.0146631'), longitude=Decimal('19.9287562')),
#  GraphNode(id=2374339651, latitude=Decimal('50.0146047'), longitude=Decimal('19.9286914')),
#  GraphNode(id=3060991899, latitude=Decimal('50.0145732'), longitude=Decimal('19.9286394')),
#  GraphNode(id=10706537753, latitude=Decimal('50.0145550'), longitude=Decimal('19.9286025')),
#  GraphNode(id=2374339641, latitude=Decimal('50.0145380'), longitude=Decimal('19.9285604')),
#  GraphNode(id=321429846, latitude=Decimal('50.0145250'), longitude=Decimal('19.9285133')),
#  GraphNode(id=2374339634, latitude=Decimal('50.0145188'), longitude=Decimal('19.9284730')),
#  GraphNode(id=2374339632, latitude=Decimal('50.0145096'), longitude=Decimal('19.9283977')),
#  GraphNode(id=3060995627, latitude=Decimal('50.0145088'), longitude=Decimal('19.9283462')),
#  GraphNode(id=10706537755, latitude=Decimal('50.0145098'), longitude=Decimal('19.9283030')),
#  GraphNode(id=2374339633, latitude=Decimal('50.0145130'), longitude=Decimal('19.9282529')),
#  GraphNode(id=10706537754, latitude=Decimal('50.0145185'), longitude=Decimal('19.9282084')),
#  GraphNode(id=321429847, latitude=Decimal('50.0145251'), longitude=Decimal('19.9281621')),
#  GraphNode(id=3060994163, latitude=Decimal('50.0145503'), longitude=Decimal('19.9280362')),
#  GraphNode(id=629106144, latitude=Decimal('50.0146050'), longitude=Decimal('19.9277901')),
#  GraphNode(id=321429848, latitude=Decimal('50.0146630'), longitude=Decimal('19.9275228')),
#  GraphNode(id=2374339660, latitude=Decimal('50.0146771'), longitude=Decimal('19.9274377')),
#  GraphNode(id=10706537756, latitude=Decimal('50.0146852'), longitude=Decimal('19.9273778')),
#  GraphNode(id=2374339663, latitude=Decimal('50.0146912'), longitude=Decimal('19.9273128')),
#  GraphNode(id=2374339664, latitude=Decimal('50.0146969'), longitude=Decimal('19.9272250')),
#  GraphNode(id=3060991900, latitude=Decimal('50.0146959'), longitude=Decimal('19.9271725')),
#  GraphNode(id=10706537757, latitude=Decimal('50.0146926'), longitude=Decimal('19.9271160')),
#  GraphNode(id=321429849, latitude=Decimal('50.0146872'), longitude=Decimal('19.9270579')),
#  GraphNode(id=2374339662, latitude=Decimal('50.0146782'), longitude=Decimal('19.9270062')),
#  GraphNode(id=10706537758, latitude=Decimal('50.0146669'), longitude=Decimal('19.9269563')),
#  GraphNode(id=3060994995, latitude=Decimal('50.0146542'), longitude=Decimal('19.9269123')),
#  GraphNode(id=10706537759, latitude=Decimal('50.0146344'), longitude=Decimal('19.9268527')),
#  GraphNode(id=321429850, latitude=Decimal('50.0146174'), longitude=Decimal('19.9268105')),
#  GraphNode(id=2374339650, latitude=Decimal('50.0145965'), longitude=Decimal('19.9267694')),
#  GraphNode(id=10706537760, latitude=Decimal('50.0145744'), longitude=Decimal('19.9267299')),
#  GraphNode(id=3060994994, latitude=Decimal('50.0145473'), longitude=Decimal('19.9266886')),
#  GraphNode(id=2374339638, latitude=Decimal('50.0145203'), longitude=Decimal('19.9266558')),
#  GraphNode(id=10706537761, latitude=Decimal('50.0144924'), longitude=Decimal('19.9266238')),
#  GraphNode(id=321429851, latitude=Decimal('50.0144617'), longitude=Decimal('19.9265948')),
# ...
#  GraphNode(id=2419959878, latitude=Decimal('50.0806136'), longitude=Decimal('19.8930008')),
#  GraphNode(id=2419959876, latitude=Decimal('50.0805520'), longitude=Decimal('19.8931768')),
#  GraphNode(id=8687940617, latitude=Decimal('50.0800066'), longitude=Decimal('19.8946764')),
#  GraphNode(id=6148308974, latitude=Decimal('50.0799237'), longitude=Decimal('19.8949044')),
#  GraphNode(id=2419959875, latitude=Decimal('50.0798133'), longitude=Decimal('19.8952082')),
#  GraphNode(id=2419959874, latitude=Decimal('50.0792294'), longitude=Decimal('19.8967465')),
#  GraphNode(id=4529384780, latitude=Decimal('50.0790658'), longitude=Decimal('19.8971755')),
#  GraphNode(id=8638111302, latitude=Decimal('50.0790545'), longitude=Decimal('19.8972064')),
#  GraphNode(id=8638111301, latitude=Decimal('50.0789945'), longitude=Decimal('19.8973704')),
#  GraphNode(id=4529384782, latitude=Decimal('50.0789700'), longitude=Decimal('19.8974373')),
#  GraphNode(id=8638111300, latitude=Decimal('50.0789553'), longitude=Decimal('19.8974769')),
#  GraphNode(id=8638111297, latitude=Decimal('50.0789372'), longitude=Decimal('19.8975256')),
#  GraphNode(id=1691818945, latitude=Decimal('50.0789248'), longitude=Decimal('19.8975588')),
#  GraphNode(id=2419959873, latitude=Decimal('50.0786373'), longitude=Decimal('19.8983333')),
#  GraphNode(id=2419959872, latitude=Decimal('50.0783179'), longitude=Decimal('19.8991996')),
#  GraphNode(id=5931579111, latitude=Decimal('50.0779313'), longitude=Decimal('19.9002337')),
#  GraphNode(id=1764579369, latitude=Decimal('50.0611958'), longitude=Decimal('19.9801769')),
#  GraphNode(id=11127450521, latitude=Decimal('50.0612075'), longitude=Decimal('19.9801977')),
#  GraphNode(id=11127450522, latitude=Decimal('50.0612186'), longitude=Decimal('19.9802143')),
#  GraphNode(id=11127450523, latitude=Decimal('50.0612291'), longitude=Decimal('19.9802272')),
#  GraphNode(id=4555749845, latitude=Decimal('50.0612451'), longitude=Decimal('19.9802430')),
#  GraphNode(id=11127450524, latitude=Decimal('50.0612670'), longitude=Decimal('19.9802615')),
#  GraphNode(id=11127450525, latitude=Decimal('50.0613235'), longitude=Decimal('19.9802973')),
#  GraphNode(id=11127450526, latitude=Decimal('50.0613527'), longitude=Decimal('19.9803089')),
#  GraphNode(id=638606076, latitude=Decimal('50.0613848'), longitude=Decimal('19.9803183')),
#  GraphNode(id=1764579374, latitude=Decimal('50.0615037'), longitude=Decimal('19.9803468')),
#  GraphNode(id=1505690439, latitude=Decimal('50.0615739'), longitude=Decimal('19.9803643')),
#  GraphNode(id=932156589, latitude=Decimal('50.0617170'), longitude=Decimal('19.9804003')),
#  GraphNode(id=1764579384, latitude=Decimal('50.0617384'), longitude=Decimal('19.9804040')),
#  GraphNode(id=11127450566, latitude=Decimal('50.0617612'), longitude=Decimal('19.9804049')),
#  GraphNode(id=9051982133, latitude=Decimal('50.0617833'), longitude=Decimal('19.9804026')),
#  GraphNode(id=11127450565, latitude=Decimal('50.0618029'), longitude=Decimal('19.9803982')),
#  GraphNode(id=1764579389, latitude=Decimal('50.0618202'), longitude=Decimal('19.9803920')),
#  GraphNode(id=9051973714, latitude=Decimal('50.0618416'), longitude=Decimal('19.9803796')),
#  GraphNode(id=638606079, latitude=Decimal('50.0618628'), longitude=Decimal('19.9803653')),
#  GraphNode(id=9051973713, latitude=Decimal('50.0618832'), longitude=Decimal('19.9803466')),
#  GraphNode(id=11127450564, latitude=Decimal('50.0619030'), longitude=Decimal('19.9803238')),
#  GraphNode(id=932156701, latitude=Decimal('50.0619183'), longitude=Decimal('19.9803029')),
#  GraphNode(id=9051973715, latitude=Decimal('50.0619308'), longitude=Decimal('19.9802825')),
#  GraphNode(id=9051973716, latitude=Decimal('50.0619429'), longitude=Decimal('19.9802573')),
#  GraphNode(id=11127450563, latitude=Decimal('50.0619556'), longitude=Decimal('19.9802244')),
#  GraphNode(id=638606081, latitude=Decimal('50.0619665'), longitude=Decimal('19.9801885')),
#  GraphNode(id=9051982117, latitude=Decimal('50.0619737'), longitude=Decimal('19.9801562')),
#  GraphNode(id=1764579418, latitude=Decimal('50.0619801'), longitude=Decimal('19.9801124')),
#  GraphNode(id=9051982118, latitude=Decimal('50.0619831'), longitude=Decimal('19.9800768')),
#  GraphNode(id=11127450562, latitude=Decimal('50.0619831'), longitude=Decimal('19.9800392')),
#  GraphNode(id=9051982119, latitude=Decimal('50.0619806'), longitude=Decimal('19.9800062')),
#  GraphNode(id=9051973712, latitude=Decimal('50.0619772'), longitude=Decimal('19.9799762')),
#  GraphNode(id=11127450561, latitude=Decimal('50.0619742'), longitude=Decimal('19.9799536')),
#  GraphNode(id=638606082, latitude=Decimal('50.0619690'), longitude=Decimal('19.9799298')),
#  GraphNode(id=9051982120, latitude=Decimal('50.0619603'), longitude=Decimal('19.9799021')),
#  GraphNode(id=11127450560, latitude=Decimal('50.0619523'), longitude=Decimal('19.9798796')),
#  GraphNode(id=638606071, latitude=Decimal('50.0619410'), longitude=Decimal('19.9798552')),
#  GraphNode(id=9051982121, latitude=Decimal('50.0619257'), longitude=Decimal('19.9798266')),
#  GraphNode(id=1764579410, latitude=Decimal('50.0619090'), longitude=Decimal('19.9797982')),
#  GraphNode(id=1764579405, latitude=Decimal('50.0618885'), longitude=Decimal('19.9797719')),
#  GraphNode(id=1764579400, latitude=Decimal('50.0618749'), longitude=Decimal('19.9797573')),
#  GraphNode(id=11127450559, latitude=Decimal('50.0618590'), longitude=Decimal('19.9797435')),
#  GraphNode(id=1764579395, latitude=Decimal('50.0618401'), longitude=Decimal('19.9797298')),
#  GraphNode(id=9051982122, latitude=Decimal('50.0618250'), longitude=Decimal('19.9797217')),
#  GraphNode(id=1764579391, latitude=Decimal('50.0618034'), longitude=Decimal('19.9797134')),
#  GraphNode(id=9051982123, latitude=Decimal('50.0617850'), longitude=Decimal('19.9797095')),
#  GraphNode(id=11127450558, latitude=Decimal('50.0617693'), longitude=Decimal('19.9797080')),
#  GraphNode(id=932156705, latitude=Decimal('50.0617542'), longitude=Decimal('19.9797078')),
#  GraphNode(id=638606074, latitude=Decimal('50.0616293'), longitude=Decimal('19.9797170')),
#  GraphNode(id=3102651994, latitude=Decimal('50.0295607'), longitude=Decimal('19.9364826')),
#  GraphNode(id=1877260188, latitude=Decimal('50.0295238'), longitude=Decimal('19.9364415')),
#  GraphNode(id=9993799602, latitude=Decimal('50.0295121'), longitude=Decimal('19.9364221')),
#  GraphNode(id=2374339749, latitude=Decimal('50.0295015'), longitude=Decimal('19.9363997')),
#  GraphNode(id=1701445138, latitude=Decimal('50.0294880'), longitude=Decimal('19.9363677')),
#  GraphNode(id=9993799603, latitude=Decimal('50.0294804'), longitude=Decimal('19.9363412')),
#  GraphNode(id=1877260186, latitude=Decimal('50.0294740'), longitude=Decimal('19.9363155')),
#  GraphNode(id=3102653323, latitude=Decimal('50.0294690'), longitude=Decimal('19.9362768')),
#  GraphNode(id=1701445137, latitude=Decimal('50.0294678'), longitude=Decimal('19.9362268')),
#  GraphNode(id=9993799601, latitude=Decimal('50.0294699'), longitude=Decimal('19.9361931')),
#  GraphNode(id=2374339748, latitude=Decimal('50.0294754'), longitude=Decimal('19.9361500')),
#  GraphNode(id=1763772057, latitude=Decimal('50.0675826'), longitude=Decimal('20.0630124')),
#  GraphNode(id=9130493772, latitude=Decimal('50.0675686'), longitude=Decimal('20.0627707')),
#  GraphNode(id=321437078, latitude=Decimal('50.0675593'), longitude=Decimal('20.0625297')),
#  GraphNode(id=10758384298, latitude=Decimal('50.0675432'), longitude=Decimal('20.0615549')),
#  GraphNode(id=10757297088, latitude=Decimal('50.0675413'), longitude=Decimal('20.0614671')),
#  GraphNode(id=10757365409, latitude=Decimal('50.0675166'), longitude=Decimal('20.0598711')),
#  GraphNode(id=10757309065, latitude=Decimal('50.0675115'), longitude=Decimal('20.0595060')),
#  GraphNode(id=11776455676, latitude=Decimal('50.0675107'), longitude=Decimal('20.0593759')),
#  GraphNode(id=11784529366, latitude=Decimal('50.0675114'), longitude=Decimal('20.0592195')),
#  GraphNode(id=11776455678, latitude=Decimal('50.0675133'), longitude=Decimal('20.0590666')),
#  GraphNode(id=11776455679, latitude=Decimal('50.0675209'), longitude=Decimal('20.0588422')),
#  GraphNode(id=11776455680, latitude=Decimal('50.0675386'), longitude=Decimal('20.0585651')),
#  GraphNode(id=11776455681, latitude=Decimal('50.0675524'), longitude=Decimal('20.0584068')),
#  GraphNode(id=11776455682, latitude=Decimal('50.0675656'), longitude=Decimal('20.0582792')),
#  GraphNode(id=11776455677, latitude=Decimal('50.0675777'), longitude=Decimal('20.0581742')),
#  GraphNode(id=9130493776, latitude=Decimal('50.0675867'), longitude=Decimal('20.0581030')),
#  GraphNode(id=10757310828, latitude=Decimal('50.0676018'), longitude=Decimal('20.0579974')),
#  GraphNode(id=1763772065, latitude=Decimal('50.0676235'), longitude=Decimal('20.0578553')),
#  GraphNode(id=11784529338, latitude=Decimal('50.0676521'), longitude=Decimal('20.0576811')),
#  GraphNode(id=1734577618, latitude=Decimal('50.0680490'), longitude=Decimal('20.0554454')),
#  GraphNode(id=773635866, latitude=Decimal('50.0684904'), longitude=Decimal('20.0529645')),
#  GraphNode(id=8355575966, latitude=Decimal('50.0685223'), longitude=Decimal('20.0527886')),
#  GraphNode(id=322763088, latitude=Decimal('50.0685551'), longitude=Decimal('20.0526070')),
#  GraphNode(id=8355575964, latitude=Decimal('50.0685830'), longitude=Decimal('20.0524450')),
#  GraphNode(id=1420852686, latitude=Decimal('50.0690232'), longitude=Decimal('20.0500062')),
#  GraphNode(id=529083475, latitude=Decimal('50.0690488'), longitude=Decimal('20.0498641')),
#  GraphNode(id=1420852690, latitude=Decimal('50.0690727'), longitude=Decimal('20.0497273')),
#  GraphNode(id=773635778, latitude=Decimal('50.0697018'), longitude=Decimal('20.0462366')),
#  GraphNode(id=1420852744, latitude=Decimal('50.0697538'), longitude=Decimal('20.0459585')),
#  GraphNode(id=773635849, latitude=Decimal('50.0697775'), longitude=Decimal('20.0458266')),
#  GraphNode(id=1420028796, latitude=Decimal('50.0697994'), longitude=Decimal('20.0457072')),
#  GraphNode(id=1420852753, latitude=Decimal('50.0702476'), longitude=Decimal('20.0432016')),
#  GraphNode(id=1420852761, latitude=Decimal('50.0704739'), longitude=Decimal('20.0419559')),
#  GraphNode(id=9130493768, latitude=Decimal('50.0705111'), longitude=Decimal('20.0417710')),
#  GraphNode(id=11618064152, latitude=Decimal('50.0705338'), longitude=Decimal('20.0416503')),
#  GraphNode(id=321437070, latitude=Decimal('50.0705594'), longitude=Decimal('20.0415321')),
#  GraphNode(id=1763772158, latitude=Decimal('50.0706002'), longitude=Decimal('20.0413434')),
#  GraphNode(id=9130493767, latitude=Decimal('50.0706354'), longitude=Decimal('20.0411812')),
#  GraphNode(id=11618064151, latitude=Decimal('50.0706985'), longitude=Decimal('20.0409182')),
#  GraphNode(id=11618064166, latitude=Decimal('50.0708169'), longitude=Decimal('20.0404433')),
#  GraphNode(id=9130493762, latitude=Decimal('50.0712918'), longitude=Decimal('20.0385790')),
#  GraphNode(id=213605074, latitude=Decimal('50.0724769'), longitude=Decimal('20.0385048')),
#  GraphNode(id=321437262, latitude=Decimal('50.0725634'), longitude=Decimal('20.0388290')),
#  GraphNode(id=8284515579, latitude=Decimal('50.0734537'), longitude=Decimal('20.0421819')),
#  GraphNode(id=8284515552, latitude=Decimal('50.0735329'), longitude=Decimal('20.0424839')),
#  GraphNode(id=8284515553, latitude=Decimal('50.0736119'), longitude=Decimal('20.0427800')),
#  GraphNode(id=213605085, latitude=Decimal('50.0745301'), longitude=Decimal('20.0462495')),
#  GraphNode(id=8284515567, latitude=Decimal('50.0746359'), longitude=Decimal('20.0466442')),
#  GraphNode(id=8284515569, latitude=Decimal('50.0747048'), longitude=Decimal('20.0469035')),
#  GraphNode(id=8284515571, latitude=Decimal('50.0747741'), longitude=Decimal('20.0471683')),
#  GraphNode(id=8284515573, latitude=Decimal('50.0753383'), longitude=Decimal('20.0492905')),
#  GraphNode(id=282709157, latitude=Decimal('50.0759775'), longitude=Decimal('20.0517078')),
#  GraphNode(id=8284515575, latitude=Decimal('50.0760863'), longitude=Decimal('20.0521163')),
#  GraphNode(id=282709166, latitude=Decimal('50.0763072'), longitude=Decimal('20.0529452')),
#  GraphNode(id=11455430036, latitude=Decimal('50.0784290'), longitude=Decimal('20.0609495')),
#  GraphNode(id=322747179, latitude=Decimal('50.0788709'), longitude=Decimal('20.0626163')),
#  GraphNode(id=8430313115, latitude=Decimal('50.0789443'), longitude=Decimal('20.0628949')),
#  GraphNode(id=213578721, latitude=Decimal('50.0790091'), longitude=Decimal('20.0632018')),
#  GraphNode(id=1764757908, latitude=Decimal('50.0790414'), longitude=Decimal('20.0634089')),
#  GraphNode(id=213578723, latitude=Decimal('50.0790667'), longitude=Decimal('20.0635966')),
#  GraphNode(id=213578726, latitude=Decimal('50.0790900'), longitude=Decimal('20.0638300')),
#  GraphNode(id=1764757915, latitude=Decimal('50.0791075'), longitude=Decimal('20.0641318')),
#  GraphNode(id=1764757917, latitude=Decimal('50.0791175'), longitude=Decimal('20.0644721')),
#  GraphNode(id=213578731, latitude=Decimal('50.0791355'), longitude=Decimal('20.0650412')),
#  GraphNode(id=8284515580, latitude=Decimal('50.0791458'), longitude=Decimal('20.0653385')),
#  GraphNode(id=322752972, latitude=Decimal('50.0950300'), longitude=Decimal('20.0125866')),
#  GraphNode(id=243358794, latitude=Decimal('50.0951703'), longitude=Decimal('20.0126081')),
#  GraphNode(id=2296425801, latitude=Decimal('50.0954521'), longitude=Decimal('20.0126524')),
#  GraphNode(id=840467685, latitude=Decimal('50.0957618'), longitude=Decimal('20.0126964')),
#  GraphNode(id=2296425823, latitude=Decimal('50.0959892'), longitude=Decimal('20.0127318')),
#  GraphNode(id=8309441574, latitude=Decimal('50.0961135'), longitude=Decimal('20.0127504')),
#  GraphNode(id=2296425850, latitude=Decimal('50.0962368'), longitude=Decimal('20.0127683')),
#  GraphNode(id=213646585, latitude=Decimal('50.0978326'), longitude=Decimal('20.0130120')),
#  GraphNode(id=2296425862, latitude=Decimal('50.0980384'), longitude=Decimal('20.0130416')),
#  GraphNode(id=8476164749, latitude=Decimal('50.0981709'), longitude=Decimal('20.0130617')),
#  GraphNode(id=2296425883, latitude=Decimal('50.0983234'), longitude=Decimal('20.0130848')),
#  GraphNode(id=11276928280, latitude=Decimal('50.0991787'), longitude=Decimal('20.0131998')),
#  GraphNode(id=2385866826, latitude=Decimal('50.0992542'), longitude=Decimal('20.0132074')),
#  GraphNode(id=213646590, latitude=Decimal('50.0993274'), longitude=Decimal('20.0132122')),
#  GraphNode(id=11276928279, latitude=Decimal('50.0994112'), longitude=Decimal('20.0132152')),
#  GraphNode(id=11276928278, latitude=Decimal('50.0995039'), longitude=Decimal('20.0132148')),
#  GraphNode(id=2385866832, latitude=Decimal('50.0995907'), longitude=Decimal('20.0132127')),
#  GraphNode(id=11276928277, latitude=Decimal('50.0996745'), longitude=Decimal('20.0132085')),
#  GraphNode(id=213646591, latitude=Decimal('50.0997629'), longitude=Decimal('20.0131988')),
#  GraphNode(id=11276928309, latitude=Decimal('50.0998849'), longitude=Decimal('20.0131810')),
#  GraphNode(id=2385866845, latitude=Decimal('50.0999878'), longitude=Decimal('20.0131606')),
#  GraphNode(id=11276928307, latitude=Decimal('50.1000822'), longitude=Decimal('20.0131393')),
#  GraphNode(id=213646593, latitude=Decimal('50.1001773'), longitude=Decimal('20.0131137')),
#  GraphNode(id=11276928305, latitude=Decimal('50.1002604'), longitude=Decimal('20.0130882')),
#  GraphNode(id=2296425989, latitude=Decimal('50.1004523'), longitude=Decimal('20.0130230')),
#  GraphNode(id=8443884951, latitude=Decimal('50.1011605'), longitude=Decimal('20.0127807')),
#  GraphNode(id=8443884950, latitude=Decimal('50.1015279'), longitude=Decimal('20.0126506')),
#  GraphNode(id=2296426058, latitude=Decimal('50.1018649'), longitude=Decimal('20.0125351')),
#  GraphNode(id=2424134783, latitude=Decimal('50.1021105'), longitude=Decimal('20.0124519')),
#  GraphNode(id=1764757729, latitude=Decimal('50.0682040'), longitude=Decimal('20.0695227')),
#  GraphNode(id=1764757730, latitude=Decimal('50.0682336'), longitude=Decimal('20.0698326')),
#  GraphNode(id=1770194214, latitude=Decimal('50.0682637'), longitude=Decimal('20.0701380')),
#  ...]

# %% [markdown]
# #### Get a list of routes between stops

# %%
cursor.execute("""
    SELECT DISTINCT
        tram_passage_stops.tram_stop_id AS start_stop_id,
        TPS.tram_stop_id AS end_stop_id
    FROM tram_passage_stops
        JOIN tram_passage_stops TPS ON tram_passage_stops.tram_passage_id = TPS.tram_passage_id
    WHERE tram_passage_stops.stop_index = TPS.stop_index - 1
""")

stops = cursor.fetchall()
len(stops)
# Out:
# 419

# %% [markdown]
# #### Get shortest route between nodes

# %%
def route_between_nodes(graph: dict[int, GraphNode], start_node_id: int, end_node_id: int):
    priority_queue: PriorityQueue[tuple[float, GraphNode]] = PriorityQueue()
    parents: dict[int, GraphNode] = {}
    distances: dict[int, float] = defaultdict(lambda: float("inf"))

    priority_queue.put((0, graph[start_node_id]))
    distances[start_node_id] = 0.0

    while priority_queue.not_empty:
        current_distance, root = priority_queue.get()

        if current_distance > distances[end_node_id]:
            break

        for node in graph[root.id].edges:
            new_distance = distances[root.id] + root.distance_to(node)

            if distances[node.id] > new_distance:
                distances[node.id] = new_distance
                parents[node.id] = root
                priority_queue.put((distances[node.id], node))

    route = [graph[end_node_id]]
    while route[-1] != graph[start_node_id]:
        route.append(parents[route[-1].id])
        
    route.append(graph[start_node_id])

    route.reverse()

    return route

# %% [markdown]
# #### Calculate routes between stops

# %%
i = 0

# %%
route = route_between_nodes(graph, *stops[i])
print(i)
i += 1

latitudes, longitudes = [item.latitude for item in route], [item.longitude for item in route]

folium_map = Map(
    location=(
        (max(latitudes) - min(latitudes)) / 2 + min(latitudes),
        (max(longitudes) - min(longitudes)) / 2 + min(longitudes),
    ),
    zoom_start=17
)

folium_map.add_child(PolyLine([item.coordinates for item in route]))

folium_map
# Out:
# 0
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9508c04b25e286afe75b1a1dadf4c44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9508c04b25e286afe75b1a1dadf4c44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9508c04b25e286afe75b1a1dadf4c44 = L.map(
#                 &quot;map_f9508c04b25e286afe75b1a1dadf4c44&quot;,
#                 {
#                     center: [50.0875358, 20.0616911],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd8a6431f90cad6922cee955a7f7296e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cd8a6431f90cad6922cee955a7f7296e.addTo(map_f9508c04b25e286afe75b1a1dadf4c44);
#
#
#             var poly_line_1beceaaa4dd40e7541a475f4c137f68d = L.polyline(
#                 [[50.0877219, 20.0639455], [50.0877219, 20.0639455], [50.0877261, 20.0637641], [50.0877636, 20.0617866], [50.0877596, 20.061561], [50.0877503, 20.0612906], [50.0877206, 20.0609727], [50.0876846, 20.0607335], [50.0876433, 20.0605277], [50.0876038, 20.0603584], [50.087599, 20.0603382], [50.0875495, 20.0601484], [50.0874294, 20.0597943], [50.087308, 20.0594367]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f9508c04b25e286afe75b1a1dadf4c44);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
